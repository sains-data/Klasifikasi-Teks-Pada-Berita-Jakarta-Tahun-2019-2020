# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('combined_data.csv')
df.head(10)
# Out:
#       tanggal                                                isu tonality  \
# 0  2019-08-01  Nasib DKI Jakarta Setelah Ibu Kota Pindah ke K...   NETRAL
# 1  2019-08-01              Integrasi Transportasi Oleh Jaklingko  POSITIF
# 2  2019-08-01              Integrasi Transportasi Oleh Jaklingko  POSITIF
# 3  2019-08-01             Pengelolaan Sampah Jakarta vs Surabaya   NETRAL
# 4  2019-08-02                        Sidang Perdana Polusi Udara   NETRAL
# 5  2019-08-02                        Sidang Perdana Polusi Udara   NETRAL
# 6  2019-08-02                        Sidang Perdana Polusi Udara   NETRAL
# 7  2019-08-02                        Sidang Perdana Polusi Udara   NETRAL
# 8  2019-08-02                        Sidang Perdana Polusi Udara   NETRAL
# 9  2019-08-02             Bantuan untuk Pencari Suaka Dihentikan   NETRAL
#
#                                       berita_jakarta  \
# 0                                                NaN
# 1  Musyawarah Kerja Daerah Organda Jakarta Anies ...
# 2  Warga Apresiasi Pengoperasian Dua Jak Lingko d...
# 3                                                NaN
# 4  Dishub Ingin Penggunaan Kendaraan Listrik Lebi...
# 5  Pemprov DKI-ICLEI Sepakati Kerja Sama Penuruna...
# 6  Terbitkan Ingub Pemprov DKI Siapkan 7 Inisiati...
# 7   DKI Matangkan Aplikasi Pemantauan Kualitas Udara
# 8  Dewan Dukung Percepatan Pengoperasian Bus List...
# 9                                                NaN
#
#                                            link/page
# 0                                                NaN
# 1  https://www.beritajakarta.id/read/70758/musyaw...
# 2  https://www.beritajakarta.id/read/70829/warga-...
# 3                                                NaN
# 4  https://www.beritajakarta.id/read/70807/dewan-...
# 5  https://www.beritajakarta.id/read/70819/pempro...
# 6  https://www.beritajakarta.id/read/70850/terbit...
# 7  https://www.beritajakarta.id/read/70888/dki-ma...
# 8  https://www.beritajakarta.id/read/70814/dishub...
# 9                                                NaN

# %%
df.tail(10)
# Out:
#          tanggal                                              isu tonality  \
# 3781  2020-09-29   Pengendalian Banjir di Tengah Pandemi COVID-19   NETRAL
# 3782  2020-09-29   Pengendalian Banjir di Tengah Pandemi COVID-19   NETRAL
# 3783  2020-09-29   Pengendalian Banjir di Tengah Pandemi COVID-19   NETRAL
# 3784  2020-09-29   Pengendalian Banjir di Tengah Pandemi COVID-19   NETRAL
# 3785  2020-09-29   Pengendalian Banjir di Tengah Pandemi COVID-19   NETRAL
# 3786  2020-09-29   Pengendalian Banjir di Tengah Pandemi COVID-19   NETRAL
# 3787  2020-09-29   Pengendalian Banjir di Tengah Pandemi COVID-19   NETRAL
# 3788  2020-09-29   Pengendalian Banjir di Tengah Pandemi COVID-19   NETRAL
# 3789  2020-09-30           Tempat Isolasi Mandiri Pasien Covid-19   NETRAL
# 3790  2020-09-30  Wajib Uji Emisi Untuk Kendaraan Berusia 3 Tahun  POSITIF
#
#                                          berita_jakarta  \
# 3781  Perbaikan 21 Pompa Stationer di Jakut Rampung ...
# 3782  DPRD Dorong Pemprov Gencarkan Kembali Kegiatan...
# 3783  Pengurasan Saluran di Pejagalan Ditarget Rampu...
# 3784  Warga Jakut Diajak Ikut Berpartisipasi Dalam P...
# 3785  Petugas PPSU Bersihkan Tali Air di Jalan Gatot...
# 3786  Petugas Bersihkan Sembilan Titik Saluran Air d...
# 3787           Saluran Air di Jl Olahraga I Dibersihkan
# 3788  Satgas Sudin SDA Jakbar Bersihkan Saluran Jl L...
# 3789  Komisi E Apresiasi Penambahan Fasilitas Isolas...
# 3790                                                NaN
#
#                                               link/page
# 3781  https://www.beritajakarta.id/read/83256/perbai...
# 3782  https://www.beritajakarta.id/read/83251/dprd-d...
# 3783  https://www.beritajakarta.id/read/83240/pengur...
# 3784  https://www.beritajakarta.id/read/83235/warga-...
# 3785  https://www.beritajakarta.id/read/83236/petuga...
# 3786  https://www.beritajakarta.id/read/83232/petuga...
# 3787  https://www.beritajakarta.id/read/83230/salura...
# 3788  https://www.beritajakarta.id/read/83227/satgas...
# 3789  https://www.beritajakarta.id/read/83310/komisi...
# 3790                                                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3791 entries, 0 to 3790
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tanggal         3791 non-null   object
#  1   isu             3791 non-null   object
#  2   tonality        3791 non-null   object
#  3   berita_jakarta  3180 non-null   object
#  4   link/page       3031 non-null   object
# dtypes: object(5)
# memory usage: 148.2+ KB

# %%
df1 = df.dropna()

# %%
df1
# Out:
#          tanggal                                             isu tonality  \
# 1     2019-08-01           Integrasi Transportasi Oleh Jaklingko  POSITIF
# 2     2019-08-01           Integrasi Transportasi Oleh Jaklingko  POSITIF
# 4     2019-08-02                     Sidang Perdana Polusi Udara   NETRAL
# 5     2019-08-02                     Sidang Perdana Polusi Udara   NETRAL
# 6     2019-08-02                     Sidang Perdana Polusi Udara   NETRAL
# ...          ...                                             ...      ...
# 3785  2020-09-29  Pengendalian Banjir di Tengah Pandemi COVID-19   NETRAL
# 3786  2020-09-29  Pengendalian Banjir di Tengah Pandemi COVID-19   NETRAL
# 3787  2020-09-29  Pengendalian Banjir di Tengah Pandemi COVID-19   NETRAL
# 3788  2020-09-29  Pengendalian Banjir di Tengah Pandemi COVID-19   NETRAL
# 3789  2020-09-30          Tempat Isolasi Mandiri Pasien Covid-19   NETRAL
#
#                                          berita_jakarta  \
# 1     Musyawarah Kerja Daerah Organda Jakarta Anies ...
# 2     Warga Apresiasi Pengoperasian Dua Jak Lingko d...
# 4     Dishub Ingin Penggunaan Kendaraan Listrik Lebi...
# 5     Pemprov DKI-ICLEI Sepakati Kerja Sama Penuruna...
# 6     Terbitkan Ingub Pemprov DKI Siapkan 7 Inisiati...
# ...                                                 ...
# 3785  Petugas PPSU Bersihkan Tali Air di Jalan Gatot...
# 3786  Petugas Bersihkan Sembilan Titik Saluran Air d...
# 3787           Saluran Air di Jl Olahraga I Dibersihkan
# 3788  Satgas Sudin SDA Jakbar Bersihkan Saluran Jl L...
# 3789  Komisi E Apresiasi Penambahan Fasilitas Isolas...
#
#                                               link/page
# 1     https://www.beritajakarta.id/read/70758/musyaw...
# 2     https://www.beritajakarta.id/read/70829/warga-...
# 4     https://www.beritajakarta.id/read/70807/dewan-...
# 5     https://www.beritajakarta.id/read/70819/pempro...
# 6     https://www.beritajakarta.id/read/70850/terbit...
# ...                                                 ...
# 3785  https://www.beritajakarta.id/read/83236/petuga...
# 3786  https://www.beritajakarta.id/read/83232/petuga...
# 3787  https://www.beritajakarta.id/read/83230/salura...
# 3788  https://www.beritajakarta.id/read/83227/satgas...
# 3789  https://www.beritajakarta.id/read/83310/komisi...
#
# [3028 rows x 5 columns]

# %%
kategori = pd.get_dummies(df.tonality)
df = pd.concat([df, kategori], axis=1)
df = df.drop(columns='tonality')
df.sample(5)
# Out:
#          tanggal                                                isu  \
# 1119  2019-01-04              Ganjil Genap Bukan Untuk Sepeda Motor
# 482   2020-04-13                        Hari Ketiga PSBB di Jakarta
# 1765  2019-06-03  Lokasi Alternatif Wisata Jakarta Saat Libur Le...
# 310   2020-08-11  Opsi Kebijakan Ganjil Genap 24 Jam di Seluruh ...
# 3302  2020-10-19          Berbagai Upaya DKI Jakarta Hadapi La Nina
#
#                                          berita_jakarta  \
# 1119                                                NaN
# 482   Pengwasan PSBB di Terminal Kampung Rambutan Di...
# 1765                  Kawasan Monas Dipadati Pengunjung
# 310       Ganjil Genap, 24 Kendaraan di Jaktim Ditilang
# 3302          Pengerukan Saluran Air Gang Macan Rampung
#
#                                               link/page  NEGATIF  NETRAL  \
# 1119                                                NaN        0       1
# 482   https://www.beritajakarta.id/read/78655/pengwa...        0       0
# 1765  https://www.beritajakarta.id/read/69274/kawasa...        0       0
# 310   https://www.beritajakarta.id/read/81950/ganjil...        0       1
# 3302  https://www.beritajakarta.id/read/83967/penger...        0       0
#
#       NETRAL   POSITIF
# 1119        0        0
# 482         0        1
# 1765        0        1
# 310         0        0
# 3302        0        1

# %%
feature = df['isu']
label = df[['NEGATIF', 'NETRAL', 'POSITIF']].values

# %%
from sklearn.model_selection import train_test_split
feature_latih, feature_test, label_latih, label_test = train_test_split(feature, label, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


pad_type = 'pre'
trunc_type = 'pre'

# Tokenize our training data
tokenizer = Tokenizer(num_words=2000, oov_token='x')
tokenizer.fit_on_texts(feature_latih)
tokenizer.fit_on_texts(feature_test)

# Encode training data sentences into sequences
sekuens_latih = tokenizer.texts_to_sequences(feature_latih)
sekuens_test = tokenizer.texts_to_sequences(feature_test)

# Get max training sequence length
maxlen = max([len(x) for x in sekuens_latih])

# Pad the training sequences
padded_latih = pad_sequences(sekuens_latih, padding=pad_type, truncating=trunc_type, maxlen=maxlen)
padded_test = pad_sequences(sekuens_test, padding=pad_type, truncating=trunc_type, maxlen=maxlen)

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Embedding(input_dim=2000, output_dim=8),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.LSTM(32),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(32, activation='sigmoid'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(3, activation='sigmoid')
  ])
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 8)           16000
#
#  dropout (Dropout)           (None, None, 8)           0
#
#  lstm (LSTM)                 (None, 32)                5248
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 32)                1056
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 22403 (87.51 KB)
# Trainable params: 22403 (87.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.9 and logs.get('val_accuracy')>0.9):
      print("\nAkurasi telah mencapai >90%!")
      self.model.stop_training = True
callbacks = myCallback()

# %%
num_epochs = 40
hist = model.fit(padded_latih, label_latih, epochs=num_epochs,
                    validation_data=(padded_test, label_test),
                    verbose=2, callbacks=[callbacks])
# Out:
# Epoch 1/40
# 95/95 - 12s - loss: 1.1050 - accuracy: 0.4535 - val_loss: 0.8182 - val_accuracy: 0.6100 - 12s/epoch - 125ms/step
# Epoch 2/40
# 95/95 - 2s - loss: 0.8951 - accuracy: 0.5482 - val_loss: 0.8182 - val_accuracy: 0.6100 - 2s/epoch - 19ms/step
# Epoch 3/40
# 95/95 - 2s - loss: 0.8640 - accuracy: 0.5739 - val_loss: 0.8151 - val_accuracy: 0.6100 - 2s/epoch - 21ms/step
# Epoch 4/40
# 95/95 - 2s - loss: 0.8386 - accuracy: 0.5953 - val_loss: 0.7726 - val_accuracy: 0.6100 - 2s/epoch - 21ms/step
# Epoch 5/40
# 95/95 - 2s - loss: 0.7518 - accuracy: 0.6675 - val_loss: 0.5962 - val_accuracy: 0.8314 - 2s/epoch - 25ms/step
# Epoch 6/40
# 95/95 - 1s - loss: 0.5809 - accuracy: 0.7988 - val_loss: 0.4671 - val_accuracy: 0.8524 - 1s/epoch - 16ms/step
# Epoch 7/40
# 95/95 - 2s - loss: 0.4610 - accuracy: 0.8529 - val_loss: 0.4303 - val_accuracy: 0.8748 - 2s/epoch - 17ms/step
# Epoch 8/40
# 95/95 - 1s - loss: 0.3872 - accuracy: 0.8912 - val_loss: 0.4169 - val_accuracy: 0.8775 - 1s/epoch - 14ms/step
# Epoch 9/40
# 95/95 - 1s - loss: 0.3623 - accuracy: 0.8954 - val_loss: 0.4039 - val_accuracy: 0.8722 - 1s/epoch - 12ms/step
# Epoch 10/40
# 95/95 - 1s - loss: 0.3275 - accuracy: 0.9040 - val_loss: 0.4251 - val_accuracy: 0.8788 - 977ms/epoch - 10ms/step
# Epoch 11/40
# 95/95 - 1s - loss: 0.2990 - accuracy: 0.9083 - val_loss: 0.4212 - val_accuracy: 0.8603 - 1s/epoch - 11ms/step
# Epoch 12/40
# 95/95 - 1s - loss: 0.2818 - accuracy: 0.9185 - val_loss: 0.4391 - val_accuracy: 0.8709 - 1s/epoch - 11ms/step
# Epoch 13/40
# 95/95 - 1s - loss: 0.2598 - accuracy: 0.9268 - val_loss: 0.4446 - val_accuracy: 0.8775 - 965ms/epoch - 10ms/step
# Epoch 14/40
# 95/95 - 1s - loss: 0.2486 - accuracy: 0.9291 - val_loss: 0.4594 - val_accuracy: 0.8643 - 1s/epoch - 11ms/step
# Epoch 15/40
# 95/95 - 1s - loss: 0.2514 - accuracy: 0.9255 - val_loss: 0.4430 - val_accuracy: 0.8696 - 974ms/epoch - 10ms/step
# Epoch 16/40
# 95/95 - 1s - loss: 0.2373 - accuracy: 0.9304 - val_loss: 0.4426 - val_accuracy: 0.8656 - 1s/epoch - 11ms/step
# Epoch 17/40
# 95/95 - 1s - loss: 0.2228 - accuracy: 0.9354 - val_loss: 0.4758 - val_accuracy: 0.8788 - 1s/epoch - 11ms/step
# Epoch 18/40
# 95/95 - 2s - loss: 0.2204 - accuracy: 0.9357 - val_loss: 0.4264 - val_accuracy: 0.8906 - 2s/epoch - 16ms/step
# Epoch 19/40
# 95/95 - 1s - loss: 0.1972 - accuracy: 0.9357 - val_loss: 0.4362 - val_accuracy: 0.8959 - 1s/epoch - 15ms/step
# Epoch 20/40
#
# Akurasi telah mencapai >90%!
# 95/95 - 1s - loss: 0.1928 - accuracy: 0.9416 - val_loss: 0.4554 - val_accuracy: 0.9012 - 1s/epoch - 13ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Prediksi label dari data uji
label_prediksi = model.predict(padded_test)
label_prediksi = [list(prediksi).index(max(prediksi)) for prediksi in label_prediksi]

# Konversi one-hot encoded labels menjadi label kelas tunggal
label_asli = [list(label).index(1) for label in label_test]

# Buat confusion matrix
cm = confusion_matrix(label_asli, label_prediksi)

# Visualisasi confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['NEGATIF', 'NETRAL', 'POSITIF'], yticklabels=['NEGATIF', 'NETRAL', 'POSITIF'])
plt.title('Confusion Matrix')
plt.show()
# Out:
# 24/24 [==============================] - 1s 5ms/step

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# function to make predictions
def make_predictions(model, tokenizer, ml):
  classes = ['Negatif', 'Netral', 'Positif']
  while True:
    text = input('Masukkan isu berita: ')
    text = [text]
    t = tokenizer.texts_to_sequences(text)
    t = pad_sequences(t, padding='pre', truncating='pre', maxlen=ml)
    pred_t = model.predict(t)
    print('Prediksi: ', classes[pred_t.argmax()])
    lagi = input('Apakah ingin mencoba lagi? (y/n) :')
    if lagi=='n' or lagi=='N':
      break

make_predictions(model, tokenizer, maxlen)
# Out:
# Masukkan isu berita: Nasib DKI Jakarta Setelah Ibu Kota Pindah ke Kalimantan
# 1/1 [==============================] - 0s 25ms/step
# Prediksi:  Netral
# Apakah ingin mencoba lagi? (y/n) :n

# %%
# Menampilkan nilai akurasi
accuracy = model.evaluate(padded_test, label_test, verbose=0)[1]
print(f"Akurasi pada data uji: {accuracy * 100:.2f}%")
# Out:
# Akurasi pada data uji: 90.12%

# %%
import pickle
# Save the model to a file
model.save('model.h5')

# Save the tokenizer to a file using pickle
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
